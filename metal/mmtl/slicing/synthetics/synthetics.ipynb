# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
import copy
from functools import partial

# %%
import numpy as np
import torch
import matplotlib.pyplot as plt

# %%
from metal.mmtl.metal_model import MetalModel
from metal.mmtl.slicing.slice_model import SliceModel
from metal.mmtl.slicing.moe_model import MoEModel

from metal.mmtl.trainer import MultitaskTrainer
from metal.mmtl.slicing.synthetics.mmtl_utils import create_tasks, create_payloads, train_slice_experts
from metal.mmtl.slicing.synthetics.data_generator import generate_data, get_circle_mask
from metal.mmtl.slicing.synthetics.viz import visualize_payload, visualize_predictions, visualize_attention, score_and_visualize
# Out:
# /lfs/1/jdunnmon/repos/anaconda3/envs/metal/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)

# %%
from metal.utils import set_seed

seed = 444
set_seed(seed)

# %% [markdown]
# ### Generate Synthetic Dataset
# We aim to build a dataset with a linear decision boundary and an abnormal boundary around $x=0.25, y=0$.
# We define this slice as our `critical_region`.

# %%
from functools import partial
flip_1 = partial(get_circle_mask, center=(0.25, 0), radius=0.2)
flip_2 = partial(get_circle_mask, center=(-0.3, -0.5), radius=0.15)

label_flips = {
    flip_1: 1,
    flip_2: 2
}
uid_lists, Xs, Ys = generate_data(N=5000, label_flips=label_flips)
task_name = "test_task"

# %% [markdown]
# #### Generate eval payload over the `critical_slice`

# %%
# targets all the data -- used to add the BASE labelset to payloads
identity_fn = lambda x: np.ones(x.shape[0], dtype=np.bool)
# NOTE: the slice function _imperfectly_ targets the critical slice area.
slice_1 = partial(get_circle_mask, center=(0.35, -0.1), radius=0.2)
slice_2 = partial(get_circle_mask, center=(-0.35, -0.4), radius=0.15)

remainder = lambda X: np.logical_not(np.logical_or(slice_1(X), slice_2(X)))

# %%
eval_payload = create_payloads(task_name, uid_lists, Xs, Ys, batch_size=1000, 
   slice_funcs={"slice_1": slice_1, "slice_2": slice_2, "remainder": remainder}
#    slice_funcs={"slice_1": flip_1, "slice_2": flip_2}
)[2] # take test set

# %%
visualize_payload(eval_payload)
# Out:
# Vizualizing labelset_gold from payload_test
# /lfs/1/jdunnmon/repos/anaconda3/envs/metal/lib/python3.6/site-packages/matplotlib/figure.py:98: MatplotlibDeprecationWarning:
# Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   "Adding an axes using the same arguments as a previous axes "
# Vizualizing labelset:slice_1:pred from payload_test
# Vizualizing labelset:slice_1:ind from payload_test
# Vizualizing labelset:slice_2:pred from payload_test
# Vizualizing labelset:slice_2:ind from payload_test
# Vizualizing labelset:remainder:pred from payload_test
# Vizualizing labelset:remainder:ind from payload_test

# %% [markdown]
# ### Initialize and train each model type

# %%
# all models to test to test
all_slice_funcs = {"slice_1": slice_1, "slice_2": slice_2, "BASE": identity_fn}
slice_loss_multiplier = 1.0 / (2*len(all_slice_funcs))

model_configs = {
    'soft_param': {
        'slice_funcs': all_slice_funcs,
        'create_ind': True,
        'model_class': SliceModel,
        'slice_weights': {
            'BASE': slice_loss_multiplier,
            'slice_1': slice_loss_multiplier, 'slice_2': slice_loss_multiplier
        }
    },
     'hard_param': {
         'slice_funcs': all_slice_funcs,
         'create_ind': False,
         'model_class': MetalModel,
         'slice_weights': {'slice_1': slice_loss_multiplier, 'slice_2': slice_loss_multiplier}
     },
     'manual_reweighting': {
         'slice_funcs': all_slice_funcs,
         'create_ind': False,
         'slice_weights': {"slice_1": 50}, # 10x weight of slice_2, everythign else default
         'model_class': MetalModel        
     },
     'moe': {
         'slice_funcs': {},
         'create_ind': False,
         'model_class': MoEModel
     },
#     'naive': {
#         'slice_funcs': {},
#         'model_class': MetalModel   
#     }
}

# %%
train_kwargs = {
    "lr": 0.01, 
    "n_epochs": 300,
    "checkpoint_best": False,
    "log_every": 5.0,
    "writer": "tensorboard", 
    "verbose": True,
    "progress_bar": False
}

# %%
# %%time
trained_models = {}
for model_name, config in model_configs.items():
    print(f"{'='*10}Initializing + Training {model_name}{'='*10}")
    slice_funcs = config['slice_funcs']
    model_class = config['model_class']
    slice_weights = config.get("slice_weights", {})
    create_ind = config.get("create_ind", True)
          
    tasks = create_tasks(
        task_name, 
        slice_names=list(slice_funcs.keys()), 
        slice_weights=slice_weights, 
        create_ind=create_ind,
        verbose=True
    )
    payloads = create_payloads(
        task_name, 
        uid_lists, 
        Xs, 
        Ys, 
        batch_size=16, 
        slice_funcs=slice_funcs, 
        create_ind=create_ind,
        verbose=True
    )
    visualize_payload(payloads[0])
          
    if model_name == 'moe':
        # train for total 300 epochs
        expert_train_kwargs = copy.deepcopy(train_kwargs)
        expert_train_kwargs['n_epochs'] = int(train_kwargs['n_epochs'] / (len(all_slice_funcs) + 1))
        experts = train_slice_experts(
            uid_lists, Xs, Ys, MetalModel, all_slice_funcs, **expert_train_kwargs
        )
        model = model_class(tasks, experts, verbose=False, seed=seed)
        trainer = MultitaskTrainer(seed=seed)
        metrics_dict = trainer.train_model(model, payloads, **expert_train_kwargs)
    else:
        model = model_class(tasks, verbose=False, seed=seed)
        trainer = MultitaskTrainer(seed=seed)
        metrics_dict = trainer.train_model(model, payloads, **train_kwargs)
    print(metrics_dict) 
    trained_models[model_name] = model
# Out:
# ==========Initializing + Training soft_param==========
# Creating 7 tasks...
# BinaryClassificationTask(name=test_task, loss_multiplier=1.00, slice_head_type=None)
# BinaryClassificationTask(name=test_task:slice_1:pred, loss_multiplier=0.17, slice_head_type=pred)
# BinaryClassificationTask(name=test_task:slice_1:ind, loss_multiplier=0.17, slice_head_type=ind)
# BinaryClassificationTask(name=test_task:slice_2:pred, loss_multiplier=0.17, slice_head_type=pred)
# BinaryClassificationTask(name=test_task:slice_2:ind, loss_multiplier=0.17, slice_head_type=ind)
# BinaryClassificationTask(name=test_task:BASE:pred, loss_multiplier=0.17, slice_head_type=pred)
# BinaryClassificationTask(name=test_task:BASE:ind, loss_multiplier=0.17, slice_head_type=ind)
# Creating 3 payloads...
# Payload(payload_train: labels_to_tasks=[{'labelset_gold': 'test_task', 'labelset:slice_1:pred': 'test_task:slice_1:pred', 'labelset:slice_1:ind': 'test_task:slice_1:ind', 'labelset:slice_2:pred': 'test_task:slice_2:pred', 'labelset:slice_2:ind': 'test_task:slice_2:ind', 'labelset:BASE:pred': 'test_task:BASE:pred', 'labelset:BASE:ind': 'test_task:BASE:ind'}], split=train)
# Payload(payload_valid: labels_to_tasks=[{'labelset_gold': 'test_task', 'labelset:slice_1:pred': 'test_task:slice_1:pred', 'labelset:slice_1:ind': 'test_task:slice_1:ind', 'labelset:slice_2:pred': 'test_task:slice_2:pred', 'labelset:slice_2:ind': 'test_task:slice_2:ind', 'labelset:BASE:pred': 'test_task:BASE:pred', 'labelset:BASE:ind': 'test_task:BASE:ind'}], split=valid)
# Payload(payload_test: labels_to_tasks=[{'labelset_gold': 'test_task', 'labelset:slice_1:pred': 'test_task:slice_1:pred', 'labelset:slice_1:ind': 'test_task:slice_1:ind', 'labelset:slice_2:pred': 'test_task:slice_2:pred', 'labelset:slice_2:ind': 'test_task:slice_2:ind', 'labelset:BASE:pred': 'test_task:BASE:pred', 'labelset:BASE:ind': 'test_task:BASE:ind'}], split=test)
# Vizualizing labelset_gold from payload_train
# /lfs/1/jdunnmon/repos/anaconda3/envs/metal/lib/python3.6/site-packages/matplotlib/figure.py:98: MatplotlibDeprecationWarning:
# Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   "Adding an axes using the same arguments as a previous axes "
# Vizualizing labelset:slice_1:pred from payload_train
# Vizualizing labelset:slice_1:ind from payload_train
# Vizualizing labelset:slice_2:pred from payload_train
# Vizualizing labelset:slice_2:ind from payload_train
# Vizualizing labelset:BASE:pred from payload_train
# Vizualizing labelset:BASE:ind from payload_train
# Beginning train loop.
# Expecting a total of approximately 2512 examples and 157 batches per epoch from 1 payload(s) in the train split.
# Writing config to /lfs/1/jdunnmon/repos/metal/logs/2019_04_29/22_22_59/config.json
# [5.0 epo]: test_task:[payload_train/labelset_gold/loss=1.50e-01, payload_valid/labelset_gold/accuracy=9.70e-01] test_task:slice_1:ind:[payload_train/labelset:slice_1:ind/loss=2.39e-02, payload_valid/labelset:slice_1:ind/accuracy=9.67e-01] test_task:slice_2:ind:[payload_train/labelset:slice_2:ind/loss=1.75e-02, payload_valid/labelset:slice_2:ind/accuracy=9.78e-01] test_task:BASE:pred:[payload_train/labelset:BASE:pred/loss=2.59e-02, payload_valid/labelset:BASE:pred/accuracy=9.73e-01] test_task:BASE:ind:[payload_train/labelset:BASE:ind/loss=4.75e-03, payload_valid/labelset:BASE:ind/accuracy=1.00e+00] test_task:slice_1:pred:[payload_train/labelset:slice_1:pred/loss=8.80e-02, payload_valid/labelset:slice_1:pred/accuracy=9.51e-01] test_task:slice_2:pred:[payload_train/labelset:slice_2:pred/loss=9.64e-02, payload_valid/labelset:slice_2:pred/accuracy=7.50e-01] model:[train/all/loss=4.48e-02, train/all/lr=1.00e-02, valid/all/loss=2.78e-02]
# [10.0 epo]: test_task:[payload_train/labelset_gold/loss=8.78e-02, payload_valid/labelset_gold/accuracy=9.70e-01] test_task:slice_1:ind:[payload_train/labelset:slice_1:ind/loss=1.79e-02, payload_valid/labelset:slice_1:ind/accuracy=9.67e-01] test_task:slice_2:ind:[payload_train/labelset:slice_2:ind/loss=1.20e-02, payload_valid/labelset:slice_2:ind/accuracy=9.78e-01] test_task:BASE:pred:[payload_train/labelset:BASE:pred/loss=1.50e-02, payload_valid/labelset:BASE:pred/accuracy=9.70e-01] test_task:BASE:ind:[payload_train/labelset:BASE:ind/loss=8.36e-05, payload_valid/labelset:BASE:ind/accuracy=1.00e+00] test_task:slice_1:pred:[payload_train/labelset:slice_1:pred/loss=6.44e-02, payload_valid/labelset:slice_1:pred/accuracy=9.27e-01] test_task:slice_2:pred:[payload_train/labelset:slice_2:pred/loss=7.35e-02, payload_valid/labelset:slice_2:pred/accuracy=8.21e-01] model:[train/all/loss=2.69e-02, train/all/lr=1.00e-02, valid/all/loss=2.69e-02]
# [15.0 epo]: test_task:[payload_train/labelset_gold/loss=8.73e-02, payload_valid/labelset_gold/accuracy=9.70e-01] test_task:slice_1:ind:[payload_train/labelset:slice_1:ind/loss=1.75e-02, payload_valid/labelset:slice_1:ind/accuracy=9.67e-01] test_task:slice_2:ind:[payload_train/labelset:slice_2:ind/loss=1.12e-02, payload_valid/labelset:slice_2:ind/accuracy=9.78e-01] test_task:BASE:pred:[payload_train/labelset:BASE:pred/loss=1.46e-02, payload_valid/labelset:BASE:pred/accuracy=9.70e-01] test_task:BASE:ind:[payload_train/labelset:BASE:ind/loss=2.86e-05, payload_valid/labelset:BASE:ind/accuracy=1.00e+00] test_task:slice_1:pred:[payload_train/labelset:slice_1:pred/loss=5.83e-02, payload_valid/labelset:slice_1:pred/accuracy=9.02e-01] test_task:slice_2:pred:[payload_train/labelset:slice_2:pred/loss=5.74e-02, payload_valid/labelset:slice_2:pred/accuracy=8.57e-01] model:[train/all/loss=2.64e-02, train/all/lr=1.00e-02, valid/all/loss=2.65e-02]
# [20.0 epo]: test_task:[payload_train/labelset_gold/loss=8.69e-02, payload_valid/labelset_gold/accuracy=9.70e-01] test_task:slice_1:ind:[payload_train/labelset:slice_1:ind/loss=1.72e-02, payload_valid/labelset:slice_1:ind/accuracy=9.67e-01] test_task:slice_2:ind:[payload_train/labelset:slice_2:ind/loss=1.11e-02, payload_valid/labelset:slice_2:ind/accuracy=9.78e-01] test_task:BASE:pred:[payload_train/labelset:BASE:pred/loss=1.44e-02, payload_valid/labelset:BASE:pred/accuracy=9.70e-01] test_task:BASE:ind:[payload_train/labelset:BASE:ind/loss=1.28e-05, payload_valid/labelset:BASE:ind/accuracy=1.00e+00] test_task:slice_1:pred:[payload_train/labelset:slice_1:pred/loss=5.63e-02, payload_valid/labelset:slice_1:pred/accuracy=9.02e-01] test_task:slice_2:pred:[payload_train/labelset:slice_2:pred/loss=4.49e-02, payload_valid/labelset:slice_2:pred/accuracy=8.93e-01] model:[train/all/loss=2.62e-02, train/all/lr=1.00e-02, valid/all/loss=2.63e-02]
# [25.0 epo]: test_task:[payload_train/labelset_gold/loss=8.66e-02, payload_valid/labelset_gold/accuracy=9.70e-01] test_task:slice_1:ind:[payload_train/labelset:slice_1:ind/loss=1.70e-02, payload_valid/labelset:slice_1:ind/accuracy=9.67e-01] test_task:slice_2:ind:[payload_train/labelset:slice_2:ind/loss=1.09e-02, payload_valid/labelset:slice_2:ind/accuracy=9.78e-01] test_task:BASE:pred:[payload_train/labelset:BASE:pred/loss=1.43e-02, payload_valid/labelset:BASE:pred/accuracy=9.70e-01] test_task:BASE:ind:[payload_train/labelset:BASE:ind/loss=6.64e-06, payload_valid/labelset:BASE:ind/accuracy=1.00e+00] test_task:slice_1:pred:[payload_train/labelset:slice_1:pred/loss=5.57e-02, payload_valid/labelset:slice_1:pred/accuracy=9.02e-01] test_task:slice_2:pred:[payload_train/labelset:slice_2:pred/loss=3.56e-02, payload_valid/labelset:slice_2:pred/accuracy=8.57e-01] model:[train/all/loss=2.60e-02, train/all/lr=1.00e-02, valid/all/loss=2.62e-02]
# [30.0 epo]: test_task:[payload_train/labelset_gold/loss=8.65e-02, payload_valid/labelset_gold/accuracy=9.70e-01] test_task:slice_1:ind:[payload_train/labelset:slice_1:ind/loss=1.67e-02, payload_valid/labelset:slice_1:ind/accuracy=9.67e-01] test_task:slice_2:ind:[payload_train/labelset:slice_2:ind/loss=1.07e-02, payload_valid/labelset:slice_2:ind/accuracy=9.78e-01] test_task:BASE:pred:[payload_train/labelset:BASE:pred/loss=1.42e-02, payload_valid/labelset:BASE:pred/accuracy=9.70e-01] test_task:BASE:ind:[payload_train/labelset:BASE:ind/loss=3.77e-06, payload_valid/labelset:BASE:ind/accuracy=1.00e+00] test_task:slice_1:pred:[payload_train/labelset:slice_1:pred/loss=5.55e-02, payload_valid/labelset:slice_1:pred/accuracy=9.02e-01] test_task:slice_2:pred:[payload_train/labelset:slice_2:pred/loss=2.88e-02, payload_valid/labelset:slice_2:pred/accuracy=8.21e-01] model:[train/all/loss=2.58e-02, train/all/lr=1.00e-02, valid/all/loss=2.61e-02]
# [35.0 epo]: test_task:[payload_train/labelset_gold/loss=8.64e-02, payload_valid/labelset_gold/accuracy=9.70e-01] test_task:slice_1:ind:[payload_train/labelset:slice_1:ind/loss=1.64e-02, payload_valid/labelset:slice_1:ind/accuracy=9.67e-01] test_task:slice_2:ind:[payload_train/labelset:slice_2:ind/loss=1.06e-02, payload_valid/labelset:slice_2:ind/accuracy=9.78e-01] test_task:BASE:pred:[payload_train/labelset:BASE:pred/loss=1.42e-02, payload_valid/labelset:BASE:pred/accuracy=9.70e-01] test_task:BASE:ind:[payload_train/labelset:BASE:ind/loss=2.36e-06, payload_valid/labelset:BASE:ind/accuracy=1.00e+00] test_task:slice_1:pred:[payload_train/labelset:slice_1:pred/loss=5.55e-02, payload_valid/labelset:slice_1:pred/accuracy=9.02e-01] test_task:slice_2:pred:[payload_train/labelset:slice_2:pred/loss=2.42e-02, payload_valid/labelset:slice_2:pred/accuracy=7.86e-01] model:[train/all/loss=2.57e-02, train/all/lr=1.00e-02, valid/all/loss=2.60e-02]
# [40.0 epo]: test_task:[payload_train/labelset_gold/loss=8.64e-02, payload_valid/labelset_gold/accuracy=9.70e-01] test_task:slice_1:ind:[payload_train/labelset:slice_1:ind/loss=1.61e-02, payload_valid/labelset:slice_1:ind/accuracy=9.67e-01] test_task:slice_2:ind:[payload_train/labelset:slice_2:ind/loss=1.04e-02, payload_valid/labelset:slice_2:ind/accuracy=9.78e-01] test_task:BASE:pred:[payload_train/labelset:BASE:pred/loss=1.42e-02, payload_valid/labelset:BASE:pred/accuracy=9.70e-01] test_task:BASE:ind:[payload_train/labelset:BASE:ind/loss=1.61e-06, payload_valid/labelset:BASE:ind/accuracy=1.00e+00] test_task:slice_1:pred:[payload_train/labelset:slice_1:pred/loss=5.56e-02, payload_valid/labelset:slice_1:pred/accuracy=9.02e-01] test_task:slice_2:pred:[payload_train/labelset:slice_2:pred/loss=2.11e-02, payload_valid/labelset:slice_2:pred/accuracy=7.86e-01] model:[train/all/loss=2.56e-02, train/all/lr=1.00e-02, valid/all/loss=2.59e-02]
# [45.0 epo]: test_task:[payload_train/labelset_gold/loss=8.63e-02, payload_valid/labelset_gold/accuracy=9.70e-01] test_task:slice_1:ind:[payload_train/labelset:slice_1:ind/loss=1.57e-02, payload_valid/labelset:slice_1:ind/accuracy=9.67e-01] test_task:slice_2:ind:[payload_train/labelset:slice_2:ind/loss=1.02e-02, payload_valid/labelset:slice_2:ind/accuracy=9.78e-01] test_task:BASE:pred:[payload_train/labelset:BASE:pred/loss=1.42e-02, payload_valid/labelset:BASE:pred/accuracy=9.70e-01] test_task:BASE:ind:[payload_train/labelset:BASE:ind/loss=1.18e-06, payload_valid/labelset:BASE:ind/accuracy=1.00e+00] test_task:slice_1:pred:[payload_train/labelset:slice_1:pred/loss=5.57e-02, payload_valid/labelset:slice_1:pred/accuracy=9.02e-01] test_task:slice_2:pred:[payload_train/labelset:slice_2:pred/loss=1.90e-02, payload_valid/labelset:slice_2:pred/accuracy=7.86e-01] model:[train/all/loss=2.54e-02, train/all/lr=1.00e-02, valid/all/loss=2.57e-02]
# [50.0 epo]: test_task:[payload_train/labelset_gold/loss=8.63e-02, payload_valid/labelset_gold/accuracy=9.70e-01] test_task:slice_1:ind:[payload_train/labelset:slice_1:ind/loss=1.53e-02, payload_valid/labelset:slice_1:ind/accuracy=9.67e-01] test_task:slice_2:ind:[payload_train/labelset:slice_2:ind/loss=9.96e-03, payload_valid/labelset:slice_2:ind/accuracy=9.78e-01] test_task:BASE:pred:[payload_train/labelset:BASE:pred/loss=1.42e-02, payload_valid/labelset:BASE:pred/accuracy=9.70e-01] test_task:BASE:ind:[payload_train/labelset:BASE:ind/loss=8.77e-07, payload_valid/labelset:BASE:ind/accuracy=1.00e+00] test_task:slice_1:pred:[payload_train/labelset:slice_1:pred/loss=5.57e-02, payload_valid/labelset:slice_1:pred/accuracy=9.02e-01] test_task:slice_2:pred:[payload_train/labelset:slice_2:pred/loss=1.75e-02, payload_valid/labelset:slice_2:pred/accuracy=8.21e-01] model:[train/all/loss=2.53e-02, train/all/lr=1.00e-02, valid/all/loss=2.56e-02]
# [55.0 epo]: test_task:[payload_train/labelset_gold/loss=8.63e-02, payload_valid/labelset_gold/accuracy=9.70e-01] test_task:slice_1:ind:[payload_train/labelset:slice_1:ind/loss=1.49e-02, payload_valid/labelset:slice_1:ind/accuracy=9.67e-01] test_task:slice_2:ind:[payload_train/labelset:slice_2:ind/loss=9.68e-03, payload_valid/labelset:slice_2:ind/accuracy=9.78e-01] test_task:BASE:pred:[payload_train/labelset:BASE:pred/loss=1.42e-02, payload_valid/labelset:BASE:pred/accuracy=9.70e-01] test_task:BASE:ind:[payload_train/labelset:BASE:ind/loss=6.79e-07, payload_valid/labelset:BASE:ind/accuracy=1.00e+00] test_task:slice_1:pred:[payload_train/labelset:slice_1:pred/loss=5.58e-02, payload_valid/labelset:slice_1:pred/accuracy=9.02e-01] test_task:slice_2:pred:[payload_train/labelset:slice_2:pred/loss=1.65e-02, payload_valid/labelset:slice_2:pred/accuracy=8.21e-01] model:[train/all/loss=2.52e-02, train/all/lr=1.00e-02, valid/all/loss=2.55e-02]
# [60.0 epo]: test_task:[payload_train/labelset_gold/loss=8.63e-02, payload_valid/labelset_gold/accuracy=9.71e-01] test_task:slice_1:ind:[payload_train/labelset:slice_1:ind/loss=1.45e-02, payload_valid/labelset:slice_1:ind/accuracy=9.67e-01] test_task:slice_2:ind:[payload_train/labelset:slice_2:ind/loss=9.38e-03, payload_valid/labelset:slice_2:ind/accuracy=9.78e-01] test_task:BASE:pred:[payload_train/labelset:BASE:pred/loss=1.42e-02, payload_valid/labelset:BASE:pred/accuracy=9.70e-01] test_task:BASE:ind:[payload_train/labelset:BASE:ind/loss=5.30e-07, payload_valid/labelset:BASE:ind/accuracy=1.00e+00] test_task:slice_1:pred:[payload_train/labelset:slice_1:pred/loss=5.58e-02, payload_valid/labelset:slice_1:pred/accuracy=9.02e-01] test_task:slice_2:pred:[payload_train/labelset:slice_2:pred/loss=1.57e-02, payload_valid/labelset:slice_2:pred/accuracy=8.21e-01] model:[train/all/loss=2.50e-02, train/all/lr=1.00e-02, valid/all/loss=2.53e-02]
# [65.0 epo]: test_task:[payload_train/labelset_gold/loss=8.63e-02, payload_valid/labelset_gold/accuracy=9.71e-01] test_task:slice_1:ind:[payload_train/labelset:slice_1:ind/loss=1.40e-02, payload_valid/labelset:slice_1:ind/accuracy=9.67e-01] test_task:slice_2:ind:[payload_train/labelset:slice_2:ind/loss=9.05e-03, payload_valid/labelset:slice_2:ind/accuracy=9.78e-01] test_task:BASE:pred:[payload_train/labelset:BASE:pred/loss=1.42e-02, payload_valid/labelset:BASE:pred/accuracy=9.70e-01] test_task:BASE:ind:[payload_train/labelset:BASE:ind/loss=4.17e-07, payload_valid/labelset:BASE:ind/accuracy=1.00e+00] test_task:slice_1:pred:[payload_train/labelset:slice_1:pred/loss=5.59e-02, payload_valid/labelset:slice_1:pred/accuracy=9.02e-01] test_task:slice_2:pred:[payload_train/labelset:slice_2:pred/loss=1.51e-02, payload_valid/labelset:slice_2:pred/accuracy=8.21e-01] model:[train/all/loss=2.49e-02, train/all/lr=1.00e-02, valid/all/loss=2.52e-02]
# [70.0 epo]: test_task:[payload_train/labelset_gold/loss=8.63e-02, payload_valid/labelset_gold/accuracy=9.71e-01] test_task:slice_1:ind:[payload_train/labelset:slice_1:ind/loss=1.34e-02, payload_valid/labelset:slice_1:ind/accuracy=9.67e-01] test_task:slice_2:ind:[payload_train/labelset:slice_2:ind/loss=8.67e-03, payload_valid/labelset:slice_2:ind/accuracy=9.78e-01] test_task:BASE:pred:[payload_train/labelset:BASE:pred/loss=1.42e-02, payload_valid/labelset:BASE:pred/accuracy=9.73e-01] test_task:BASE:ind:[payload_train/labelset:BASE:ind/loss=3.21e-07, payload_valid/labelset:BASE:ind/accuracy=1.00e+00] test_task:slice_1:pred:[payload_train/labelset:slice_1:pred/loss=5.60e-02, payload_valid/labelset:slice_1:pred/accuracy=9.02e-01] test_task:slice_2:pred:[payload_train/labelset:slice_2:pred/loss=1.47e-02, payload_valid/labelset:slice_2:pred/accuracy=8.21e-01] model:[train/all/loss=2.47e-02, train/all/lr=1.00e-02, valid/all/loss=2.50e-02]
# [75.0 epo]: test_task:[payload_train/labelset_gold/loss=8.64e-02, payload_valid/labelset_gold/accuracy=9.71e-01] test_task:slice_1:ind:[payload_train/labelset:slice_1:ind/loss=1.28e-02, payload_valid/labelset:slice_1:ind/accuracy=9.67e-01] test_task:slice_2:ind:[payload_train/labelset:slice_2:ind/loss=8.28e-03, payload_valid/labelset:slice_2:ind/accuracy=9.78e-01] test_task:BASE:pred:[payload_train/labelset:BASE:pred/loss=1.42e-02, payload_valid/labelset:BASE:pred/accuracy=9.73e-01] test_task:BASE:ind:[payload_train/labelset:BASE:ind/loss=2.42e-07, payload_valid/labelset:BASE:ind/accuracy=1.00e+00] test_task:slice_1:pred:[payload_train/labelset:slice_1:pred/loss=5.60e-02, payload_valid/labelset:slice_1:pred/accuracy=9.02e-01] test_task:slice_2:pred:[payload_train/labelset:slice_2:pred/loss=1.45e-02, payload_valid/labelset:slice_2:pred/accuracy=8.21e-01] model:[train/all/loss=2.45e-02, train/all/lr=1.00e-02, valid/all/loss=2.48e-02]
# [80.0 epo]: test_task:[payload_train/labelset_gold/loss=8.64e-02, payload_valid/labelset_gold/accuracy=9.72e-01] test_task:slice_1:ind:[payload_train/labelset:slice_1:ind/loss=1.22e-02, payload_valid/labelset:slice_1:ind/accuracy=9.67e-01] test_task:slice_2:ind:[payload_train/labelset:slice_2:ind/loss=7.94e-03, payload_valid/labelset:slice_2:ind/accuracy=9.78e-01] test_task:BASE:pred:[payload_train/labelset:BASE:pred/loss=1.42e-02, payload_valid/labelset:BASE:pred/accuracy=9.73e-01] test_task:BASE:ind:[payload_train/labelset:BASE:ind/loss=1.71e-07, payload_valid/labelset:BASE:ind/accuracy=1.00e+00] test_task:slice_1:pred:[payload_train/labelset:slice_1:pred/loss=5.60e-02, payload_valid/labelset:slice_1:pred/accuracy=9.02e-01] test_task:slice_2:pred:[payload_train/labelset:slice_2:pred/loss=1.44e-02, payload_valid/labelset:slice_2:pred/accuracy=8.21e-01] model:[train/all/loss=2.43e-02, train/all/lr=1.00e-02, valid/all/loss=2.47e-02]
# [85.0 epo]: test_task:[payload_train/labelset_gold/loss=8.64e-02, payload_valid/labelset_gold/accuracy=9.72e-01] test_task:slice_1:ind:[payload_train/labelset:slice_1:ind/loss=1.17e-02, payload_valid/labelset:slice_1:ind/accuracy=9.67e-01] test_task:slice_2:ind:[payload_train/labelset:slice_2:ind/loss=7.71e-03, payload_valid/labelset:slice_2:ind/accuracy=9.78e-01] test_task:BASE:pred:[payload_train/labelset:BASE:pred/loss=1.42e-02, payload_valid/labelset:BASE:pred/accuracy=9.73e-01] test_task:BASE:ind:[payload_train/labelset:BASE:ind/loss=1.08e-07, payload_valid/labelset:BASE:ind/accuracy=1.00e+00] test_task:slice_1:pred:[payload_train/labelset:slice_1:pred/loss=5.60e-02, payload_valid/labelset:slice_1:pred/accuracy=9.02e-01] test_task:slice_2:pred:[payload_train/labelset:slice_2:pred/loss=1.41e-02, payload_valid/labelset:slice_2:pred/accuracy=8.21e-01] model:[train/all/loss=2.42e-02, train/all/lr=1.00e-02, valid/all/loss=2.45e-02]
# [90.0 epo]: test_task:[payload_train/labelset_gold/loss=8.64e-02, payload_valid/labelset_gold/accuracy=9.72e-01] test_task:slice_1:ind:[payload_train/labelset:slice_1:ind/loss=1.13e-02, payload_valid/labelset:slice_1:ind/accuracy=9.67e-01] test_task:slice_2:ind:[payload_train/labelset:slice_2:ind/loss=7.53e-03, payload_valid/labelset:slice_2:ind/accuracy=9.78e-01] test_task:BASE:pred:[payload_train/labelset:BASE:pred/loss=1.42e-02, payload_valid/labelset:BASE:pred/accuracy=9.74e-01] test_task:BASE:ind:[payload_train/labelset:BASE:ind/loss=6.25e-08, payload_valid/labelset:BASE:ind/accuracy=1.00e+00] test_task:slice_1:pred:[payload_train/labelset:slice_1:pred/loss=5.59e-02, payload_valid/labelset:slice_1:pred/accuracy=9.02e-01] test_task:slice_2:pred:[payload_train/labelset:slice_2:pred/loss=1.41e-02, payload_valid/labelset:slice_2:pred/accuracy=8.21e-01] model:[train/all/loss=2.41e-02, train/all/lr=1.00e-02, valid/all/loss=2.44e-02]
# [95.0 epo]: test_task:[payload_train/labelset_gold/loss=8.65e-02, payload_valid/labelset_gold/accuracy=9.72e-01] test_task:slice_1:ind:[payload_train/labelset:slice_1:ind/loss=1.08e-02, payload_valid/labelset:slice_1:ind/accuracy=9.72e-01] test_task:slice_2:ind:[payload_train/labelset:slice_2:ind/loss=7.36e-03, payload_valid/labelset:slice_2:ind/accuracy=9.78e-01] test_task:BASE:pred:[payload_train/labelset:BASE:pred/loss=1.42e-02, payload_valid/labelset:BASE:pred/accuracy=9.74e-01] test_task:BASE:ind:[payload_train/labelset:BASE:ind/loss=3.72e-08, payload_valid/labelset:BASE:ind/accuracy=1.00e+00] test_task:slice_1:pred:[payload_train/labelset:slice_1:pred/loss=5.58e-02, payload_valid/labelset:slice_1:pred/accuracy=9.02e-01] test_task:slice_2:pred:[payload_train/labelset:slice_2:pred/loss=1.46e-02, payload_valid/labelset:slice_2:pred/accuracy=8.21e-01] model:[train/all/loss=2.39e-02, train/all/lr=1.00e-02, valid/all/loss=2.43e-02]
# [100.0 epo]: test_task:[payload_train/labelset_gold/loss=8.64e-02, payload_valid/labelset_gold/accuracy=9.72e-01] test_task:slice_1:ind:[payload_train/labelset:slice_1:ind/loss=1.04e-02, payload_valid/labelset:slice_1:ind/accuracy=9.74e-01] test_task:slice_2:ind:[payload_train/labelset:slice_2:ind/loss=7.22e-03, payload_valid/labelset:slice_2:ind/accuracy=9.78e-01] test_task:BASE:pred:[payload_train/labelset:BASE:pred/loss=1.42e-02, payload_valid/labelset:BASE:pred/accuracy=9.74e-01] test_task:BASE:ind:[payload_train/labelset:BASE:ind/loss=2.37e-08, payload_valid/labelset:BASE:ind/accuracy=1.00e+00] test_task:slice_1:pred:[payload_train/labelset:slice_1:pred/loss=5.57e-02, payload_valid/labelset:slice_1:pred/accuracy=9.02e-01] test_task:slice_2:pred:[payload_train/labelset:slice_2:pred/loss=1.50e-02, payload_valid/labelset:slice_2:pred/accuracy=8.21e-01] model:[train/all/loss=2.38e-02, train/all/lr=1.00e-02, valid/all/loss=2.41e-02]
# [105.0 epo]: test_task:[payload_train/labelset_gold/loss=8.64e-02, payload_valid/labelset_gold/accuracy=9.72e-01] test_task:slice_1:ind:[payload_train/labelset:slice_1:ind/loss=9.99e-03, payload_valid/labelset:slice_1:ind/accuracy=9.74e-01] test_task:slice_2:ind:[payload_train/labelset:slice_2:ind/loss=7.08e-03, payload_valid/labelset:slice_2:ind/accuracy=9.78e-01] test_task:BASE:pred:[payload_train/labelset:BASE:pred/loss=1.42e-02, payload_valid/labelset:BASE:pred/accuracy=9.74e-01] test_task:BASE:ind:[payload_train/labelset:BASE:ind/loss=1.55e-08, payload_valid/labelset:BASE:ind/accuracy=1.00e+00] test_task:slice_1:pred:[payload_train/labelset:slice_1:pred/loss=5.57e-02, payload_valid/labelset:slice_1:pred/accuracy=9.02e-01] test_task:slice_2:pred:[payload_train/labelset:slice_2:pred/loss=1.53e-02, payload_valid/labelset:slice_2:pred/accuracy=7.86e-01] model:[train/all/loss=2.37e-02, train/all/lr=1.00e-02, valid/all/loss=2.40e-02]
# [110.0 epo]: test_task:[payload_train/labelset_gold/loss=8.64e-02, payload_valid/labelset_gold/accuracy=9.72e-01] test_task:slice_1:ind:[payload_train/labelset:slice_1:ind/loss=9.64e-03, payload_valid/labelset:slice_1:ind/accuracy=9.76e-01] test_task:slice_2:ind:[payload_train/labelset:slice_2:ind/loss=6.96e-03, payload_valid/labelset:slice_2:ind/accuracy=9.78e-01] test_task:BASE:pred:[payload_train/labelset:BASE:pred/loss=1.42e-02, payload_valid/labelset:BASE:pred/accuracy=9.74e-01] test_task:BASE:ind:[payload_train/labelset:BASE:ind/loss=1.01e-08, payload_valid/labelset:BASE:ind/accuracy=1.00e+00] test_task:slice_1:pred:[payload_train/labelset:slice_1:pred/loss=5.56e-02, payload_valid/labelset:slice_1:pred/accuracy=9.02e-01] test_task:slice_2:pred:[payload_train/labelset:slice_2:pred/loss=1.56e-02, payload_valid/labelset:slice_2:pred/accuracy=7.50e-01] model:[train/all/loss=2.36e-02, train/all/lr=1.00e-02, valid/all/loss=2.39e-02]
# [115.0 epo]: test_task:[payload_train/labelset_gold/loss=8.63e-02, payload_valid/labelset_gold/accuracy=9.72e-01] test_task:slice_1:ind:[payload_train/labelset:slice_1:ind/loss=9.34e-03, payload_valid/labelset:slice_1:ind/accuracy=9.78e-01] test_task:slice_2:ind:[payload_train/labelset:slice_2:ind/loss=6.85e-03, payload_valid/labelset:slice_2:ind/accuracy=9.78e-01] test_task:BASE:pred:[payload_train/labelset:BASE:pred/loss=1.42e-02, payload_valid/labelset:BASE:pred/accuracy=9.74e-01] test_task:BASE:ind:[payload_train/labelset:BASE:ind/loss=6.79e-09, payload_valid/labelset:BASE:ind/accuracy=1.00e+00] test_task:slice_1:pred:[payload_train/labelset:slice_1:pred/loss=5.56e-02, payload_valid/labelset:slice_1:pred/accuracy=9.02e-01] test_task:slice_2:pred:[payload_train/labelset:slice_2:pred/loss=1.58e-02, payload_valid/labelset:slice_2:pred/accuracy=7.50e-01] model:[train/all/loss=2.35e-02, train/all/lr=1.00e-02, valid/all/loss=2.38e-02]
# [120.0 epo]: test_task:[payload_train/labelset_gold/loss=8.63e-02, payload_valid/labelset_gold/accuracy=9.72e-01] test_task:slice_1:ind:[payload_train/labelset:slice_1:ind/loss=9.13e-03, payload_valid/labelset:slice_1:ind/accuracy=9.77e-01] test_task:slice_2:ind:[payload_train/labelset:slice_2:ind/loss=6.76e-03, payload_valid/labelset:slice_2:ind/accuracy=9.78e-01] test_task:BASE:pred:[payload_train/labelset:BASE:pred/loss=1.42e-02, payload_valid/labelset:BASE:pred/accuracy=9.73e-01] test_task:BASE:ind:[payload_train/labelset:BASE:ind/loss=4.30e-09, payload_valid/labelset:BASE:ind/accuracy=1.00e+00] test_task:slice_1:pred:[payload_train/labelset:slice_1:pred/loss=5.55e-02, payload_valid/labelset:slice_1:pred/accuracy=9.02e-01] test_task:slice_2:pred:[payload_train/labelset:slice_2:pred/loss=1.57e-02, payload_valid/labelset:slice_2:pred/accuracy=7.50e-01] model:[train/all/loss=2.34e-02, train/all/lr=1.00e-02, valid/all/loss=2.38e-02]
# [125.0 epo]: test_task:[payload_train/labelset_gold/loss=8.62e-02, payload_valid/labelset_gold/accuracy=9.72e-01] test_task:slice_1:ind:[payload_train/labelset:slice_1:ind/loss=8.93e-03, payload_valid/labelset:slice_1:ind/accuracy=9.77e-01] test_task:slice_2:ind:[payload_train/labelset:slice_2:ind/loss=6.67e-03, payload_valid/labelset:slice_2:ind/accuracy=9.78e-01] test_task:BASE:pred:[payload_train/labelset:BASE:pred/loss=1.42e-02, payload_valid/labelset:BASE:pred/accuracy=9.73e-01] test_task:BASE:ind:[payload_train/labelset:BASE:ind/loss=2.83e-09, payload_valid/labelset:BASE:ind/accuracy=1.00e+00] test_task:slice_1:pred:[payload_train/labelset:slice_1:pred/loss=5.54e-02, payload_valid/labelset:slice_1:pred/accuracy=9.02e-01] test_task:slice_2:pred:[payload_train/labelset:slice_2:pred/loss=1.56e-02, payload_valid/labelset:slice_2:pred/accuracy=7.50e-01] model:[train/all/loss=2.34e-02, train/all/lr=1.00e-02, valid/all/loss=2.37e-02]
# [130.0 epo]: test_task:[payload_train/labelset_gold/loss=8.62e-02, payload_valid/labelset_gold/accuracy=9.72e-01] test_task:slice_1:ind:[payload_train/labelset:slice_1:ind/loss=8.79e-03, payload_valid/labelset:slice_1:ind/accuracy=9.78e-01] test_task:slice_2:ind:[payload_train/labelset:slice_2:ind/loss=6.58e-03, payload_valid/labelset:slice_2:ind/accuracy=9.78e-01] test_task:BASE:pred:[payload_train/labelset:BASE:pred/loss=1.42e-02, payload_valid/labelset:BASE:pred/accuracy=9.73e-01] test_task:BASE:ind:[payload_train/labelset:BASE:ind/loss=1.62e-09, payload_valid/labelset:BASE:ind/accuracy=1.00e+00] test_task:slice_1:pred:[payload_train/labelset:slice_1:pred/loss=5.54e-02, payload_valid/labelset:slice_1:pred/accuracy=9.02e-01] test_task:slice_2:pred:[payload_train/labelset:slice_2:pred/loss=1.54e-02, payload_valid/labelset:slice_2:pred/accuracy=7.86e-01] model:[train/all/loss=2.33e-02, train/all/lr=1.00e-02, valid/all/loss=2.37e-02]
# [135.0 epo]: test_task:[payload_train/labelset_gold/loss=8.61e-02, payload_valid/labelset_gold/accuracy=9.72e-01] test_task:slice_1:ind:[payload_train/labelset:slice_1:ind/loss=8.64e-03, payload_valid/labelset:slice_1:ind/accuracy=9.79e-01] test_task:slice_2:ind:[payload_train/labelset:slice_2:ind/loss=6.50e-03, payload_valid/labelset:slice_2:ind/accuracy=9.78e-01] test_task:BASE:pred:[payload_train/labelset:BASE:pred/loss=1.42e-02, payload_valid/labelset:BASE:pred/accuracy=9.74e-01] test_task:BASE:ind:[payload_train/labelset:BASE:ind/loss=7.65e-10, payload_valid/labelset:BASE:ind/accuracy=1.00e+00] test_task:slice_1:pred:[payload_train/labelset:slice_1:pred/loss=5.54e-02, payload_valid/labelset:slice_1:pred/accuracy=9.02e-01] test_task:slice_2:pred:[payload_train/labelset:slice_2:pred/loss=1.52e-02, payload_valid/labelset:slice_2:pred/accuracy=7.86e-01] model:[train/all/loss=2.33e-02, train/all/lr=1.00e-02, valid/all/loss=2.36e-02]
# [140.0 epo]: test_task:[payload_train/labelset_gold/loss=8.61e-02, payload_valid/labelset_gold/accuracy=9.72e-01] test_task:slice_1:ind:[payload_train/labelset:slice_1:ind/loss=8.50e-03, payload_valid/labelset:slice_1:ind/accuracy=9.79e-01] test_task:slice_2:ind:[payload_train/labelset:slice_2:ind/loss=6.42e-03, payload_valid/labelset:slice_2:ind/accuracy=9.78e-01] test_task:BASE:pred:[payload_train/labelset:BASE:pred/loss=1.42e-02, payload_valid/labelset:BASE:pred/accuracy=9.74e-01] test_task:BASE:ind:[payload_train/labelset:BASE:ind/loss=2.94e-10, payload_valid/labelset:BASE:ind/accuracy=1.00e+00] test_task:slice_1:pred:[payload_train/labelset:slice_1:pred/loss=5.54e-02, payload_valid/labelset:slice_1:pred/accuracy=9.02e-01] test_task:slice_2:pred:[payload_train/labelset:slice_2:pred/loss=1.49e-02, payload_valid/labelset:slice_2:pred/accuracy=7.86e-01] model:[train/all/loss=2.32e-02, train/all/lr=1.00e-02, valid/all/loss=2.36e-02]
# [145.0 epo]: test_task:[payload_train/labelset_gold/loss=8.61e-02, payload_valid/labelset_gold/accuracy=9.72e-01] test_task:slice_1:ind:[payload_train/labelset:slice_1:ind/loss=8.38e-03, payload_valid/labelset:slice_1:ind/accuracy=9.79e-01] test_task:slice_2:ind:[payload_train/labelset:slice_2:ind/loss=6.35e-03, payload_valid/labelset:slice_2:ind/accuracy=9.78e-01] test_task:BASE:pred:[payload_train/labelset:BASE:pred/loss=1.42e-02, payload_valid/labelset:BASE:pred/accuracy=9.74e-01] test_task:BASE:ind:[payload_train/labelset:BASE:ind/loss=5.25e-11, payload_valid/labelset:BASE:ind/accuracy=1.00e+00] test_task:slice_1:pred:[payload_train/labelset:slice_1:pred/loss=5.53e-02, payload_valid/labelset:slice_1:pred/accuracy=9.02e-01] test_task:slice_2:pred:[payload_train/labelset:slice_2:pred/loss=1.47e-02, payload_valid/labelset:slice_2:pred/accuracy=7.86e-01] model:[train/all/loss=2.32e-02, train/all/lr=1.00e-02, valid/all/loss=2.35e-02]
# [150.0 epo]: test_task:[payload_train/labelset_gold/loss=8.60e-02, payload_valid/labelset_gold/accuracy=9.72e-01] test_task:slice_1:ind:[payload_train/labelset:slice_1:ind/loss=8.25e-03, payload_valid/labelset:slice_1:ind/accuracy=9.81e-01] test_task:slice_2:ind:[payload_train/labelset:slice_2:ind/loss=6.29e-03, payload_valid/labelset:slice_2:ind/accuracy=9.78e-01] test_task:BASE:pred:[payload_train/labelset:BASE:pred/loss=1.42e-02, payload_valid/labelset:BASE:pred/accuracy=9.74e-01] test_task:BASE:ind:[payload_train/labelset:BASE:ind/loss=0.00e+00, payload_valid/labelset:BASE:ind/accuracy=1.00e+00] test_task:slice_1:pred:[payload_train/labelset:slice_1:pred/loss=5.53e-02, payload_valid/labelset:slice_1:pred/accuracy=9.02e-01] test_task:slice_2:pred:[payload_train/labelset:slice_2:pred/loss=1.45e-02, payload_valid/labelset:slice_2:pred/accuracy=7.86e-01] model:[train/all/loss=2.31e-02, train/all/lr=1.00e-02, valid/all/loss=2.35e-02]
# [155.0 epo]: test_task:[payload_train/labelset_gold/loss=8.60e-02, payload_valid/labelset_gold/accuracy=9.72e-01] test_task:slice_1:ind:[payload_train/labelset:slice_1:ind/loss=7.94e-03, payload_valid/labelset:slice_1:ind/accuracy=9.82e-01] test_task:slice_2:ind:[payload_train/labelset:slice_2:ind/loss=6.22e-03, payload_valid/labelset:slice_2:ind/accuracy=9.78e-01] test_task:BASE:pred:[payload_train/labelset:BASE:pred/loss=1.43e-02, payload_valid/labelset:BASE:pred/accuracy=9.74e-01] test_task:BASE:ind:[payload_train/labelset:BASE:ind/loss=0.00e+00, payload_valid/labelset:BASE:ind/accuracy=1.00e+00] test_task:slice_1:pred:[payload_train/labelset:slice_1:pred/loss=5.51e-02, payload_valid/labelset:slice_1:pred/accuracy=9.02e-01] test_task:slice_2:pred:[payload_train/labelset:slice_2:pred/loss=1.43e-02, payload_valid/labelset:slice_2:pred/accuracy=7.86e-01] model:[train/all/loss=2.31e-02, train/all/lr=1.00e-02, valid/all/loss=2.34e-02]
# [160.0 epo]: test_task:[payload_train/labelset_gold/loss=8.59e-02, payload_valid/labelset_gold/accuracy=9.72e-01] test_task:slice_1:ind:[payload_train/labelset:slice_1:ind/loss=7.59e-03, payload_valid/labelset:slice_1:ind/accuracy=9.82e-01] test_task:slice_2:ind:[payload_train/labelset:slice_2:ind/loss=6.16e-03, payload_valid/labelset:slice_2:ind/accuracy=9.79e-01] test_task:BASE:pred:[payload_train/labelset:BASE:pred/loss=1.44e-02, payload_valid/labelset:BASE:pred/accuracy=9.73e-01] test_task:BASE:ind:[payload_train/labelset:BASE:ind/loss=0.00e+00, payload_valid/labelset:BASE:ind/accuracy=1.00e+00] test_task:slice_1:pred:[payload_train/labelset:slice_1:pred/loss=5.50e-02, payload_valid/labelset:slice_1:pred/accuracy=9.02e-01] test_task:slice_2:pred:[payload_train/labelset:slice_2:pred/loss=1.41e-02, payload_valid/labelset:slice_2:pred/accuracy=7.86e-01] model:[train/all/loss=2.30e-02, train/all/lr=1.00e-02, valid/all/loss=2.33e-02]
# [165.0 epo]: test_task:[payload_train/labelset_gold/loss=8.57e-02, payload_valid/labelset_gold/accuracy=9.72e-01] test_task:slice_1:ind:[payload_train/labelset:slice_1:ind/loss=7.06e-03, payload_valid/labelset:slice_1:ind/accuracy=9.85e-01] test_task:slice_2:ind:[payload_train/labelset:slice_2:ind/loss=6.11e-03, payload_valid/labelset:slice_2:ind/accuracy=9.79e-01] test_task:BASE:pred:[payload_train/labelset:BASE:pred/loss=1.44e-02, payload_valid/labelset:BASE:pred/accuracy=9.73e-01] test_task:BASE:ind:[payload_train/labelset:BASE:ind/loss=0.00e+00, payload_valid/labelset:BASE:ind/accuracy=1.00e+00] test_task:slice_1:pred:[payload_train/labelset:slice_1:pred/loss=5.50e-02, payload_valid/labelset:slice_1:pred/accuracy=9.02e-01] test_task:slice_2:pred:[payload_train/labelset:slice_2:pred/loss=1.40e-02, payload_valid/labelset:slice_2:pred/accuracy=7.86e-01] model:[train/all/loss=2.28e-02, train/all/lr=1.00e-02, valid/all/loss=2.31e-02]
# [170.0 epo]: test_task:[payload_train/labelset_gold/loss=8.54e-02, payload_valid/labelset_gold/accuracy=9.71e-01] test_task:slice_1:ind:[payload_train/labelset:slice_1:ind/loss=6.31e-03, payload_valid/labelset:slice_1:ind/accuracy=9.86e-01] test_task:slice_2:ind:[payload_train/labelset:slice_2:ind/loss=6.06e-03, payload_valid/labelset:slice_2:ind/accuracy=9.79e-01] test_task:BASE:pred:[payload_train/labelset:BASE:pred/loss=1.44e-02, payload_valid/labelset:BASE:pred/accuracy=9.72e-01] test_task:BASE:ind:[payload_train/labelset:BASE:ind/loss=0.00e+00, payload_valid/labelset:BASE:ind/accuracy=1.00e+00] test_task:slice_1:pred:[payload_train/labelset:slice_1:pred/loss=5.51e-02, payload_valid/labelset:slice_1:pred/accuracy=9.02e-01] test_task:slice_2:pred:[payload_train/labelset:slice_2:pred/loss=1.38e-02, payload_valid/labelset:slice_2:pred/accuracy=7.86e-01] model:[train/all/loss=2.26e-02, train/all/lr=1.00e-02, valid/all/loss=2.29e-02]
# [175.0 epo]: test_task:[payload_train/labelset_gold/loss=8.46e-02, payload_valid/labelset_gold/accuracy=9.70e-01] test_task:slice_1:ind:[payload_train/labelset:slice_1:ind/loss=5.66e-03, payload_valid/labelset:slice_1:ind/accuracy=9.83e-01] test_task:slice_2:ind:[payload_train/labelset:slice_2:ind/loss=6.03e-03, payload_valid/labelset:slice_2:ind/accuracy=9.79e-01] test_task:BASE:pred:[payload_train/labelset:BASE:pred/loss=1.46e-02, payload_valid/labelset:BASE:pred/accuracy=9.70e-01] test_task:BASE:ind:[payload_train/labelset:BASE:ind/loss=0.00e+00, payload_valid/labelset:BASE:ind/accuracy=1.00e+00] test_task:slice_1:pred:[payload_train/labelset:slice_1:pred/loss=5.52e-02, payload_valid/labelset:slice_1:pred/accuracy=9.02e-01] test_task:slice_2:pred:[payload_train/labelset:slice_2:pred/loss=1.37e-02, payload_valid/labelset:slice_2:pred/accuracy=8.21e-01] model:[train/all/loss=2.24e-02, train/all/lr=1.00e-02, valid/all/loss=2.27e-02]
# [180.0 epo]: test_task:[payload_train/labelset_gold/loss=8.34e-02, payload_valid/labelset_gold/accuracy=9.70e-01] test_task:slice_1:ind:[payload_train/labelset:slice_1:ind/loss=4.90e-03, payload_valid/labelset:slice_1:ind/accuracy=9.86e-01] test_task:slice_2:ind:[payload_train/labelset:slice_2:ind/loss=6.03e-03, payload_valid/labelset:slice_2:ind/accuracy=9.79e-01] test_task:BASE:pred:[payload_train/labelset:BASE:pred/loss=1.50e-02, payload_valid/labelset:BASE:pred/accuracy=9.70e-01] test_task:BASE:ind:[payload_train/labelset:BASE:ind/loss=0.00e+00, payload_valid/labelset:BASE:ind/accuracy=1.00e+00] test_task:slice_1:pred:[payload_train/labelset:slice_1:pred/loss=5.48e-02, payload_valid/labelset:slice_1:pred/accuracy=9.02e-01] test_task:slice_2:pred:[payload_train/labelset:slice_2:pred/loss=1.42e-02, payload_valid/labelset:slice_2:pred/accuracy=8.21e-01] model:[train/all/loss=2.20e-02, train/all/lr=1.00e-02, valid/all/loss=2.25e-02]
# [185.0 epo]: test_task:[payload_train/labelset_gold/loss=8.24e-02, payload_valid/labelset_gold/accuracy=9.70e-01] test_task:slice_1:ind:[payload_train/labelset:slice_1:ind/loss=4.65e-03, payload_valid/labelset:slice_1:ind/accuracy=9.87e-01] test_task:slice_2:ind:[payload_train/labelset:slice_2:ind/loss=6.02e-03, payload_valid/labelset:slice_2:ind/accuracy=9.79e-01] test_task:BASE:pred:[payload_train/labelset:BASE:pred/loss=1.52e-02, payload_valid/labelset:BASE:pred/accuracy=9.70e-01] test_task:BASE:ind:[payload_train/labelset:BASE:ind/loss=0.00e+00, payload_valid/labelset:BASE:ind/accuracy=1.00e+00] test_task:slice_1:pred:[payload_train/labelset:slice_1:pred/loss=5.38e-02, payload_valid/labelset:slice_1:pred/accuracy=9.02e-01] test_task:slice_2:pred:[payload_train/labelset:slice_2:pred/loss=1.41e-02, payload_valid/labelset:slice_2:pred/accuracy=8.21e-01] model:[train/all/loss=2.18e-02, train/all/lr=1.00e-02, valid/all/loss=2.24e-02]
# [190.0 epo]: test_task:[payload_train/labelset_gold/loss=8.17e-02, payload_valid/labelset_gold/accuracy=9.71e-01] test_task:slice_1:ind:[payload_train/labelset:slice_1:ind/loss=4.51e-03, payload_valid/labelset:slice_1:ind/accuracy=9.86e-01] test_task:slice_2:ind:[payload_train/labelset:slice_2:ind/loss=6.02e-03, payload_valid/labelset:slice_2:ind/accuracy=9.79e-01] test_task:BASE:pred:[payload_train/labelset:BASE:pred/loss=1.54e-02, payload_valid/labelset:BASE:pred/accuracy=9.70e-01] test_task:BASE:ind:[payload_train/labelset:BASE:ind/loss=0.00e+00, payload_valid/labelset:BASE:ind/accuracy=1.00e+00] test_task:slice_1:pred:[payload_train/labelset:slice_1:pred/loss=5.28e-02, payload_valid/labelset:slice_1:pred/accuracy=9.02e-01] test_task:slice_2:pred:[payload_train/labelset:slice_2:pred/loss=1.42e-02, payload_valid/labelset:slice_2:pred/accuracy=8.21e-01] model:[train/all/loss=2.17e-02, train/all/lr=1.00e-02, valid/all/loss=2.24e-02]
# [195.0 epo]: test_task:[payload_train/labelset_gold/loss=8.12e-02, payload_valid/labelset_gold/accuracy=9.70e-01] test_task:slice_1:ind:[payload_train/labelset:slice_1:ind/loss=4.38e-03, payload_valid/labelset:slice_1:ind/accuracy=9.88e-01] test_task:slice_2:ind:[payload_train/labelset:slice_2:ind/loss=6.02e-03, payload_valid/labelset:slice_2:ind/accuracy=9.81e-01] test_task:BASE:pred:[payload_train/labelset:BASE:pred/loss=1.55e-02, payload_valid/labelset:BASE:pred/accuracy=9.70e-01] test_task:BASE:ind:[payload_train/labelset:BASE:ind/loss=0.00e+00, payload_valid/labelset:BASE:ind/accuracy=1.00e+00] test_task:slice_1:pred:[payload_train/labelset:slice_1:pred/loss=5.16e-02, payload_valid/labelset:slice_1:pred/accuracy=9.02e-01] test_task:slice_2:pred:[payload_train/labelset:slice_2:pred/loss=1.43e-02, payload_valid/labelset:slice_2:pred/accuracy=8.21e-01] model:[train/all/loss=2.16e-02, train/all/lr=1.00e-02, valid/all/loss=2.23e-02]
# [200.0 epo]: test_task:[payload_train/labelset_gold/loss=8.08e-02, payload_valid/labelset_gold/accuracy=9.70e-01] test_task:slice_1:ind:[payload_train/labelset:slice_1:ind/loss=4.29e-03, payload_valid/labelset:slice_1:ind/accuracy=9.88e-01] test_task:slice_2:ind:[payload_train/labelset:slice_2:ind/loss=6.02e-03, payload_valid/labelset:slice_2:ind/accuracy=9.82e-01] test_task:BASE:pred:[payload_train/labelset:BASE:pred/loss=1.57e-02, payload_valid/labelset:BASE:pred/accuracy=9.68e-01] test_task:BASE:ind:[payload_train/labelset:BASE:ind/loss=0.00e+00, payload_valid/labelset:BASE:ind/accuracy=1.00e+00] test_task:slice_1:pred:[payload_train/labelset:slice_1:pred/loss=5.04e-02, payload_valid/labelset:slice_1:pred/accuracy=9.02e-01] test_task:slice_2:pred:[payload_train/labelset:slice_2:pred/loss=1.45e-02, payload_valid/labelset:slice_2:pred/accuracy=8.21e-01] model:[train/all/loss=2.15e-02, train/all/lr=1.00e-02, valid/all/loss=2.22e-02]
# [205.0 epo]: test_task:[payload_train/labelset_gold/loss=8.04e-02, payload_valid/labelset_gold/accuracy=9.69e-01] test_task:slice_1:ind:[payload_train/labelset:slice_1:ind/loss=4.17e-03, payload_valid/labelset:slice_1:ind/accuracy=9.86e-01] test_task:slice_2:ind:[payload_train/labelset:slice_2:ind/loss=6.02e-03, payload_valid/labelset:slice_2:ind/accuracy=9.82e-01] test_task:BASE:pred:[payload_train/labelset:BASE:pred/loss=1.58e-02, payload_valid/labelset:BASE:pred/accuracy=9.68e-01] test_task:BASE:ind:[payload_train/labelset:BASE:ind/loss=0.00e+00, payload_valid/labelset:BASE:ind/accuracy=1.00e+00] test_task:slice_1:pred:[payload_train/labelset:slice_1:pred/loss=4.90e-02, payload_valid/labelset:slice_1:pred/accuracy=9.27e-01] test_task:slice_2:pred:[payload_train/labelset:slice_2:pred/loss=1.47e-02, payload_valid/labelset:slice_2:pred/accuracy=8.21e-01] model:[train/all/loss=2.14e-02, train/all/lr=1.00e-02, valid/all/loss=2.22e-02]
# [210.0 epo]: test_task:[payload_train/labelset_gold/loss=7.99e-02, payload_valid/labelset_gold/accuracy=9.69e-01] test_task:slice_1:ind:[payload_train/labelset:slice_1:ind/loss=4.09e-03, payload_valid/labelset:slice_1:ind/accuracy=9.89e-01] test_task:slice_2:ind:[payload_train/labelset:slice_2:ind/loss=6.02e-03, payload_valid/labelset:slice_2:ind/accuracy=9.82e-01] test_task:BASE:pred:[payload_train/labelset:BASE:pred/loss=1.59e-02, payload_valid/labelset:BASE:pred/accuracy=9.66e-01] test_task:BASE:ind:[payload_train/labelset:BASE:ind/loss=0.00e+00, payload_valid/labelset:BASE:ind/accuracy=1.00e+00] test_task:slice_1:pred:[payload_train/labelset:slice_1:pred/loss=4.76e-02, payload_valid/labelset:slice_1:pred/accuracy=9.27e-01] test_task:slice_2:pred:[payload_train/labelset:slice_2:pred/loss=1.35e-02, payload_valid/labelset:slice_2:pred/accuracy=8.21e-01] model:[train/all/loss=2.13e-02, train/all/lr=1.00e-02, valid/all/loss=2.21e-02]
# [215.0 epo]: test_task:[payload_train/labelset_gold/loss=7.95e-02, payload_valid/labelset_gold/accuracy=9.69e-01] test_task:slice_1:ind:[payload_train/labelset:slice_1:ind/loss=3.98e-03, payload_valid/labelset:slice_1:ind/accuracy=9.90e-01] test_task:slice_2:ind:[payload_train/labelset:slice_2:ind/loss=6.02e-03, payload_valid/labelset:slice_2:ind/accuracy=9.82e-01] test_task:BASE:pred:[payload_train/labelset:BASE:pred/loss=1.60e-02, payload_valid/labelset:BASE:pred/accuracy=9.65e-01] test_task:BASE:ind:[payload_train/labelset:BASE:ind/loss=0.00e+00, payload_valid/labelset:BASE:ind/accuracy=1.00e+00] test_task:slice_1:pred:[payload_train/labelset:slice_1:pred/loss=4.62e-02, payload_valid/labelset:slice_1:pred/accuracy=9.27e-01] test_task:slice_2:pred:[payload_train/labelset:slice_2:pred/loss=1.17e-02, payload_valid/labelset:slice_2:pred/accuracy=7.86e-01] model:[train/all/loss=2.12e-02, train/all/lr=1.00e-02, valid/all/loss=2.20e-02]
# [220.0 epo]: test_task:[payload_train/labelset_gold/loss=7.91e-02, payload_valid/labelset_gold/accuracy=9.69e-01] test_task:slice_1:ind:[payload_train/labelset:slice_1:ind/loss=3.91e-03, payload_valid/labelset:slice_1:ind/accuracy=9.90e-01] test_task:slice_2:ind:[payload_train/labelset:slice_2:ind/loss=6.03e-03, payload_valid/labelset:slice_2:ind/accuracy=9.82e-01] test_task:BASE:pred:[payload_train/labelset:BASE:pred/loss=1.62e-02, payload_valid/labelset:BASE:pred/accuracy=9.64e-01] test_task:BASE:ind:[payload_train/labelset:BASE:ind/loss=0.00e+00, payload_valid/labelset:BASE:ind/accuracy=1.00e+00] test_task:slice_1:pred:[payload_train/labelset:slice_1:pred/loss=4.47e-02, payload_valid/labelset:slice_1:pred/accuracy=9.27e-01] test_task:slice_2:pred:[payload_train/labelset:slice_2:pred/loss=1.12e-02, payload_valid/labelset:slice_2:pred/accuracy=7.86e-01] model:[train/all/loss=2.12e-02, train/all/lr=1.00e-02, valid/all/loss=2.20e-02]
# [225.0 epo]: test_task:[payload_train/labelset_gold/loss=7.88e-02, payload_valid/labelset_gold/accuracy=9.69e-01] test_task:slice_1:ind:[payload_train/labelset:slice_1:ind/loss=3.87e-03, payload_valid/labelset:slice_1:ind/accuracy=9.90e-01] test_task:slice_2:ind:[payload_train/labelset:slice_2:ind/loss=6.04e-03, payload_valid/labelset:slice_2:ind/accuracy=9.82e-01] test_task:BASE:pred:[payload_train/labelset:BASE:pred/loss=1.63e-02, payload_valid/labelset:BASE:pred/accuracy=9.63e-01] test_task:BASE:ind:[payload_train/labelset:BASE:ind/loss=0.00e+00, payload_valid/labelset:BASE:ind/accuracy=1.00e+00] test_task:slice_1:pred:[payload_train/labelset:slice_1:pred/loss=4.33e-02, payload_valid/labelset:slice_1:pred/accuracy=9.02e-01] test_task:slice_2:pred:[payload_train/labelset:slice_2:pred/loss=1.14e-02, payload_valid/labelset:slice_2:pred/accuracy=7.86e-01] model:[train/all/loss=2.11e-02, train/all/lr=1.00e-02, valid/all/loss=2.19e-02]
# [230.0 epo]: test_task:[payload_train/labelset_gold/loss=7.45e-02, payload_valid/labelset_gold/accuracy=9.76e-01] test_task:slice_1:ind:[payload_train/labelset:slice_1:ind/loss=4.15e-03, payload_valid/labelset:slice_1:ind/accuracy=9.86e-01] test_task:slice_2:ind:[payload_train/labelset:slice_2:ind/loss=6.06e-03, payload_valid/labelset:slice_2:ind/accuracy=9.82e-01] test_task:BASE:pred:[payload_train/labelset:BASE:pred/loss=1.63e-02, payload_valid/labelset:BASE:pred/accuracy=9.68e-01] test_task:BASE:ind:[payload_train/labelset:BASE:ind/loss=5.01e-04, payload_valid/labelset:BASE:ind/accuracy=1.00e+00] test_task:slice_1:pred:[payload_train/labelset:slice_1:pred/loss=4.19e-02, payload_valid/labelset:slice_1:pred/accuracy=9.76e-01] test_task:slice_2:pred:[payload_train/labelset:slice_2:pred/loss=1.24e-02, payload_valid/labelset:slice_2:pred/accuracy=8.21e-01] model:[train/all/loss=2.04e-02, train/all/lr=1.00e-02, valid/all/loss=1.88e-02]
# [235.0 epo]: test_task:[payload_train/labelset_gold/loss=5.58e-02, payload_valid/labelset_gold/accuracy=9.81e-01] test_task:slice_1:ind:[payload_train/labelset:slice_1:ind/loss=4.11e-03, payload_valid/labelset:slice_1:ind/accuracy=9.90e-01] test_task:slice_2:ind:[payload_train/labelset:slice_2:ind/loss=6.33e-03, payload_valid/labelset:slice_2:ind/accuracy=9.85e-01] test_task:BASE:pred:[payload_train/labelset:BASE:pred/loss=1.63e-02, payload_valid/labelset:BASE:pred/accuracy=9.68e-01] test_task:BASE:ind:[payload_train/labelset:BASE:ind/loss=1.66e-03, payload_valid/labelset:BASE:ind/accuracy=1.00e+00] test_task:slice_1:pred:[payload_train/labelset:slice_1:pred/loss=4.14e-02, payload_valid/labelset:slice_1:pred/accuracy=9.51e-01] test_task:slice_2:pred:[payload_train/labelset:slice_2:pred/loss=1.63e-02, payload_valid/labelset:slice_2:pred/accuracy=8.21e-01] model:[train/all/loss=1.70e-02, train/all/lr=1.00e-02, valid/all/loss=1.78e-02]
# ...
# Creating 1 tasks...
# BinaryClassificationTask(name=expert:slice_1:pred, loss_multiplier=1.00, slice_head_type=pred)
# Creating 3 payloads...
# Payload(payload_train: labels_to_tasks=[{'labelset:slice_1:pred': 'expert:slice_1:pred'}], split=train)
# Payload(payload_valid: labels_to_tasks=[{'labelset:slice_1:pred': 'expert:slice_1:pred'}], split=valid)
# Payload(payload_test: labels_to_tasks=[{'labelset:slice_1:pred': 'expert:slice_1:pred'}], split=test)
# [BinaryClassificationTask(name=expert:slice_1:pred, loss_multiplier=1.00, slice_head_type=pred)]
# [Payload(payload_train: labels_to_tasks=[{'labelset:slice_1:pred': 'expert:slice_1:pred'}], split=train), Payload(payload_valid: labels_to_tasks=[{'labelset:slice_1:pred': 'expert:slice_1:pred'}], split=valid), Payload(payload_test: labels_to_tasks=[{'labelset:slice_1:pred': 'expert:slice_1:pred'}], split=test)]
# Using GPU...
#
# Network architecture:
# MetalModel(
#   (input_modules): ModuleDict(
#     (expert:slice_1:pred): DataParallel(
#       (module): MetalModuleWrapper(
#         (module): Sequential(
#           (0): Linear(in_features=2, out_features=5, bias=True)
#           (1): ReLU()
#         )
#       )
#     )
#   )
#   (middle_modules): ModuleDict(
#     (expert:slice_1:pred): DataParallel(
#       (module): MetalModuleWrapper(
#         (module): IdentityModule()
#       )
#     )
#   )
#   (attention_modules): ModuleDict(
#     (expert:slice_1:pred): DataParallel(
#       (module): MetalModuleWrapper(
#         (module): IdentityModule()
#       )
#     )
#   )
#   (head_modules): ModuleDict(
#     (expert:slice_1:pred): DataParallel(
#       (module): MetalModuleWrapper(
#         (module): Linear(in_features=5, out_features=1, bias=True)
#       )
#     )
#   )
# )
#
# Total number of parameters: 21
# Beginning train loop.
# Expecting a total of approximately 2512 examples and 157 batches per epoch from 1 payload(s) in the train split.
# Writing config to /lfs/1/jdunnmon/repos/metal/logs/2019_04_29/22_43_36/config.json
# [5.0 epo]: expert:slice_1:pred:[payload_train/labelset:slice_1:pred/loss=5.47e-01, payload_valid/labelset:slice_1:pred/accuracy=7.80e-01] model:[train/all/loss=5.47e-01, train/all/lr=1.00e-02, valid/all/loss=3.44e-01]
# [10.0 epo]: expert:slice_1:pred:[payload_train/labelset:slice_1:pred/loss=3.54e-01, payload_valid/labelset:slice_1:pred/accuracy=8.05e-01] model:[train/all/loss=3.54e-01, train/all/lr=1.00e-02, valid/all/loss=2.57e-01]
# [15.0 epo]: expert:slice_1:pred:[payload_train/labelset:slice_1:pred/loss=3.16e-01, payload_valid/labelset:slice_1:pred/accuracy=9.02e-01] model:[train/all/loss=3.16e-01, train/all/lr=1.00e-02, valid/all/loss=2.03e-01]
# [20.0 epo]: expert:slice_1:pred:[payload_train/labelset:slice_1:pred/loss=3.16e-01, payload_valid/labelset:slice_1:pred/accuracy=9.51e-01] model:[train/all/loss=3.16e-01, train/all/lr=1.00e-02, valid/all/loss=1.68e-01]
# [25.0 epo]: expert:slice_1:pred:[payload_train/labelset:slice_1:pred/loss=3.25e-01, payload_valid/labelset:slice_1:pred/accuracy=9.27e-01] model:[train/all/loss=3.25e-01, train/all/lr=1.00e-02, valid/all/loss=1.88e-01]
# Finished training
# {'expert:slice_1:pred/payload_test/labelset:slice_1:pred/accuracy': 0.9117647058823529}
# Cleaning checkpoints
# Writing metrics to /lfs/1/jdunnmon/repos/metal/logs/2019_04_29/22_43_36/metrics.json
# Writing log to /lfs/1/jdunnmon/repos/metal/logs/2019_04_29/22_43_36/log.json
# /lfs/1/jdunnmon/repos/metal/metal/mmtl/trainer.py:915: UserWarning: MeTaL does not support calculating loss on the test set.
#   warnings.warn(msg)
# Full model saved at /lfs/1/jdunnmon/repos/metal/logs/2019_04_29/22_43_36/model.pkl
# {'expert:slice_1:pred/payload_test/labelset:slice_1:pred/accuracy': 0.9117647058823529}
# Creating 1 tasks...
# BinaryClassificationTask(name=expert:slice_2:pred, loss_multiplier=1.00, slice_head_type=pred)
# Creating 3 payloads...
# Payload(payload_train: labels_to_tasks=[{'labelset:slice_2:pred': 'expert:slice_2:pred'}], split=train)
# Payload(payload_valid: labels_to_tasks=[{'labelset:slice_2:pred': 'expert:slice_2:pred'}], split=valid)
# Payload(payload_test: labels_to_tasks=[{'labelset:slice_2:pred': 'expert:slice_2:pred'}], split=test)
# [BinaryClassificationTask(name=expert:slice_2:pred, loss_multiplier=1.00, slice_head_type=pred)]
# [Payload(payload_train: labels_to_tasks=[{'labelset:slice_2:pred': 'expert:slice_2:pred'}], split=train), Payload(payload_valid: labels_to_tasks=[{'labelset:slice_2:pred': 'expert:slice_2:pred'}], split=valid), Payload(payload_test: labels_to_tasks=[{'labelset:slice_2:pred': 'expert:slice_2:pred'}], split=test)]
# Using GPU...
#
# Network architecture:
# MetalModel(
#   (input_modules): ModuleDict(
#     (expert:slice_2:pred): DataParallel(
#       (module): MetalModuleWrapper(
#         (module): Sequential(
#           (0): Linear(in_features=2, out_features=5, bias=True)
#           (1): ReLU()
#         )
#       )
#     )
#   )
#   (middle_modules): ModuleDict(
#     (expert:slice_2:pred): DataParallel(
#       (module): MetalModuleWrapper(
#         (module): IdentityModule()
#       )
#     )
#   )
#   (attention_modules): ModuleDict(
#     (expert:slice_2:pred): DataParallel(
#       (module): MetalModuleWrapper(
#         (module): IdentityModule()
#       )
#     )
#   )
#   (head_modules): ModuleDict(
#     (expert:slice_2:pred): DataParallel(
#       (module): MetalModuleWrapper(
#         (module): Linear(in_features=5, out_features=1, bias=True)
#       )
#     )
#   )
# )
#
# Total number of parameters: 21
# Beginning train loop.
# Expecting a total of approximately 2512 examples and 157 batches per epoch from 1 payload(s) in the train split.
# Writing config to /lfs/1/jdunnmon/repos/metal/logs/2019_04_29/22_43_59/config.json
# [5.0 epo]: expert:slice_2:pred:[payload_train/labelset:slice_2:pred/loss=5.80e-01, payload_valid/labelset:slice_2:pred/accuracy=6.43e-01] model:[train/all/loss=5.80e-01, train/all/lr=1.00e-02, valid/all/loss=5.55e-01]
# [10.0 epo]: expert:slice_2:pred:[payload_train/labelset:slice_2:pred/loss=2.53e-01, payload_valid/labelset:slice_2:pred/accuracy=8.57e-01] model:[train/all/loss=2.53e-01, train/all/lr=1.00e-02, valid/all/loss=2.91e-01]
# [15.0 epo]: expert:slice_2:pred:[payload_train/labelset:slice_2:pred/loss=1.26e-01, payload_valid/labelset:slice_2:pred/accuracy=7.86e-01] model:[train/all/loss=1.26e-01, train/all/lr=1.00e-02, valid/all/loss=2.82e-01]
# Finished training
# {'expert:slice_2:pred/payload_test/labelset:slice_2:pred/accuracy': 0.84375}
# Cleaning checkpoints
# /lfs/1/jdunnmon/repos/metal/metal/mmtl/trainer.py:915: UserWarning: MeTaL does not support calculating loss on the test set.
#   warnings.warn(msg)
# Writing metrics to /lfs/1/jdunnmon/repos/metal/logs/2019_04_29/22_43_59/metrics.json
# Writing log to /lfs/1/jdunnmon/repos/metal/logs/2019_04_29/22_43_59/log.json
# Full model saved at /lfs/1/jdunnmon/repos/metal/logs/2019_04_29/22_43_59/model.pkl
# {'expert:slice_2:pred/payload_test/labelset:slice_2:pred/accuracy': 0.84375}
# Creating 1 tasks...
# BinaryClassificationTask(name=expert:BASE:pred, loss_multiplier=1.00, slice_head_type=pred)
# Creating 3 payloads...
# Payload(payload_train: labels_to_tasks=[{'labelset:BASE:pred': 'expert:BASE:pred'}], split=train)
# Payload(payload_valid: labels_to_tasks=[{'labelset:BASE:pred': 'expert:BASE:pred'}], split=valid)
# Payload(payload_test: labels_to_tasks=[{'labelset:BASE:pred': 'expert:BASE:pred'}], split=test)
# [BinaryClassificationTask(name=expert:BASE:pred, loss_multiplier=1.00, slice_head_type=pred)]
# [Payload(payload_train: labels_to_tasks=[{'labelset:BASE:pred': 'expert:BASE:pred'}], split=train), Payload(payload_valid: labels_to_tasks=[{'labelset:BASE:pred': 'expert:BASE:pred'}], split=valid), Payload(payload_test: labels_to_tasks=[{'labelset:BASE:pred': 'expert:BASE:pred'}], split=test)]
# Using GPU...
#
# Network architecture:
# MetalModel(
#   (input_modules): ModuleDict(
#     (expert:BASE:pred): DataParallel(
#       (module): MetalModuleWrapper(
#         (module): Sequential(
#           (0): Linear(in_features=2, out_features=5, bias=True)
#           (1): ReLU()
#         )
#       )
#     )
#   )
#   (middle_modules): ModuleDict(
#     (expert:BASE:pred): DataParallel(
#       (module): MetalModuleWrapper(
#         (module): IdentityModule()
#       )
#     )
#   )
#   (attention_modules): ModuleDict(
#     (expert:BASE:pred): DataParallel(
#       (module): MetalModuleWrapper(
#         (module): IdentityModule()
#       )
#     )
#   )
#   (head_modules): ModuleDict(
#     (expert:BASE:pred): DataParallel(
#       (module): MetalModuleWrapper(
#         (module): Linear(in_features=5, out_features=1, bias=True)
#       )
#     )
#   )
# )
#
# Total number of parameters: 21
# Beginning train loop.
# Expecting a total of approximately 2512 examples and 157 batches per epoch from 1 payload(s) in the train split.
# Writing config to /lfs/1/jdunnmon/repos/metal/logs/2019_04_29/22_44_18/config.json
# [5.0 epo]: expert:BASE:pred:[payload_train/labelset:BASE:pred/loss=1.52e-01, payload_valid/labelset:BASE:pred/accuracy=9.70e-01] model:[train/all/loss=1.52e-01, train/all/lr=1.00e-02, valid/all/loss=8.57e-02]
# [10.0 epo]: expert:BASE:pred:[payload_train/labelset:BASE:pred/loss=8.61e-02, payload_valid/labelset:BASE:pred/accuracy=9.70e-01] model:[train/all/loss=8.61e-02, train/all/lr=1.00e-02, valid/all/loss=8.49e-02]
# [15.0 epo]: expert:BASE:pred:[payload_train/labelset:BASE:pred/loss=8.59e-02, payload_valid/labelset:BASE:pred/accuracy=9.71e-01] model:[train/all/loss=8.59e-02, train/all/lr=1.00e-02, valid/all/loss=8.49e-02]
# [20.0 epo]: expert:BASE:pred:[payload_train/labelset:BASE:pred/loss=8.58e-02, payload_valid/labelset:BASE:pred/accuracy=9.71e-01] model:[train/all/loss=8.58e-02, train/all/lr=1.00e-02, valid/all/loss=8.49e-02]
# [25.0 epo]: expert:BASE:pred:[payload_train/labelset:BASE:pred/loss=8.57e-02, payload_valid/labelset:BASE:pred/accuracy=9.71e-01] model:[train/all/loss=8.57e-02, train/all/lr=1.00e-02, valid/all/loss=8.48e-02]
# [30.0 epo]: expert:BASE:pred:[payload_train/labelset:BASE:pred/loss=8.57e-02, payload_valid/labelset:BASE:pred/accuracy=9.71e-01] model:[train/all/loss=8.57e-02, train/all/lr=1.00e-02, valid/all/loss=8.48e-02]
# [35.0 epo]: expert:BASE:pred:[payload_train/labelset:BASE:pred/loss=8.56e-02, payload_valid/labelset:BASE:pred/accuracy=9.71e-01] model:[train/all/loss=8.56e-02, train/all/lr=1.00e-02, valid/all/loss=8.48e-02]
# [40.0 epo]: expert:BASE:pred:[payload_train/labelset:BASE:pred/loss=8.56e-02, payload_valid/labelset:BASE:pred/accuracy=9.71e-01] model:[train/all/loss=8.56e-02, train/all/lr=1.00e-02, valid/all/loss=8.48e-02]
# [45.0 epo]: expert:BASE:pred:[payload_train/labelset:BASE:pred/loss=8.56e-02, payload_valid/labelset:BASE:pred/accuracy=9.71e-01] model:[train/all/loss=8.56e-02, train/all/lr=1.00e-02, valid/all/loss=8.48e-02]
# [50.0 epo]: expert:BASE:pred:[payload_train/labelset:BASE:pred/loss=8.55e-02, payload_valid/labelset:BASE:pred/accuracy=9.71e-01] model:[train/all/loss=8.55e-02, train/all/lr=1.00e-02, valid/all/loss=8.48e-02]
# [55.0 epo]: expert:BASE:pred:[payload_train/labelset:BASE:pred/loss=8.55e-02, payload_valid/labelset:BASE:pred/accuracy=9.71e-01] model:[train/all/loss=8.55e-02, train/all/lr=1.00e-02, valid/all/loss=8.48e-02]
# [60.0 epo]: expert:BASE:pred:[payload_train/labelset:BASE:pred/loss=8.55e-02, payload_valid/labelset:BASE:pred/accuracy=9.71e-01] model:[train/all/loss=8.55e-02, train/all/lr=1.00e-02, valid/all/loss=8.48e-02]
# [65.0 epo]: expert:BASE:pred:[payload_train/labelset:BASE:pred/loss=8.55e-02, payload_valid/labelset:BASE:pred/accuracy=9.71e-01] model:[train/all/loss=8.55e-02, train/all/lr=1.00e-02, valid/all/loss=8.48e-02]
# [70.0 epo]: expert:BASE:pred:[payload_train/labelset:BASE:pred/loss=8.54e-02, payload_valid/labelset:BASE:pred/accuracy=9.71e-01] model:[train/all/loss=8.54e-02, train/all/lr=1.00e-02, valid/all/loss=8.48e-02]
# [75.0 epo]: expert:BASE:pred:[payload_train/labelset:BASE:pred/loss=8.54e-02, payload_valid/labelset:BASE:pred/accuracy=9.71e-01] model:[train/all/loss=8.54e-02, train/all/lr=1.00e-02, valid/all/loss=8.48e-02]
# Finished training
# {'expert:BASE:pred/payload_test/labelset:BASE:pred/accuracy': 0.9648}
# Cleaning checkpoints
# Writing metrics to /lfs/1/jdunnmon/repos/metal/logs/2019_04_29/22_44_18/metrics.json
# Writing log to /lfs/1/jdunnmon/repos/metal/logs/2019_04_29/22_44_18/log.json
# /lfs/1/jdunnmon/repos/metal/metal/mmtl/trainer.py:915: UserWarning: MeTaL does not support calculating loss on the test set.
#   warnings.warn(msg)
# Full model saved at /lfs/1/jdunnmon/repos/metal/logs/2019_04_29/22_44_18/model.pkl
# {'expert:BASE:pred/payload_test/labelset:BASE:pred/accuracy': 0.9648}
# Beginning train loop.
# Expecting a total of approximately 2512 examples and 157 batches per epoch from 1 payload(s) in the train split.
# Writing config to /lfs/1/jdunnmon/repos/metal/logs/2019_04_29/22_44_55/config.json
# Exception ignored in: <generator object tqdm_notebook.__iter__ at 0x7ff335d5f570>
# Traceback (most recent call last):
#   File "/lfs/1/jdunnmon/repos/anaconda3/envs/metal/lib/python3.6/site-packages/tqdm/_tqdm_notebook.py", line 226, in __iter__
#     self.sp(bar_style='danger')
# AttributeError: 'tqdm_notebook' object has no attribute 'sp'
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <timed exec> in <module>()
#
# /lfs/1/jdunnmon/repos/metal/metal/mmtl/trainer.py in train_model(self, model, payloads, **kwargs)
#     237                 # Counts stores the number of examples in each batch with labels by task
#     238                 loss_dict, count_dict = model.calculate_loss(
# --> 239                     *batch, payload_name, labels_to_tasks
#     240                 )
#     241
#
# /lfs/1/jdunnmon/repos/metal/metal/mmtl/metal_model.py in calculate_loss(self, X, Ys, payload_name, labels_to_tasks)
#     130         """
#     131         task_names = set(labels_to_tasks.values())
# --> 132         outputs = self.forward(X, task_names)
#     133         loss_dict = {}  # Stores the loss by task
#     134         count_dict = {}  # Stores the number of active examples by task
#
# /lfs/1/jdunnmon/repos/metal/metal/mmtl/slicing/moe_model.py in forward(self, X, task_names)
#      84
#      85         gating_input = torch.cat((expert_preds, body["data"]), dim=1)
# ---> 86         expert_weights = self.G(gating_input)
#      87
#      88         # compute weighted average of expert preds
#
# /lfs/1/jdunnmon/repos/anaconda3/envs/metal/lib/python3.6/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     487             result = self._slow_forward(*input, **kwargs)
#     488         else:
# --> 489             result = self.forward(*input, **kwargs)
#     490         for hook in self._forward_hooks.values():
#     491             hook_result = hook(self, input, result)
#
# /lfs/1/jdunnmon/repos/metal/metal/mmtl/slicing/moe_model.py in forward(self, x)
#     102
#     103     def forward(self, x):
# --> 104         out = self.fc(x)
#     105         return F.softmax(out, dim=1)
#
# /lfs/1/jdunnmon/repos/anaconda3/envs/metal/lib/python3.6/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     487             result = self._slow_forward(*input, **kwargs)
#     488         else:
# --> 489             result = self.forward(*input, **kwargs)
#     490         for hook in self._forward_hooks.values():
#     491             hook_result = hook(self, input, result)
#
# /lfs/1/jdunnmon/repos/anaconda3/envs/metal/lib/python3.6/site-packages/torch/nn/modules/linear.py in forward(self, input)
#      65     @weak_script_method
#      66     def forward(self, input):
# ---> 67         return F.linear(input, self.weight, self.bias)
#      68
#      69     def extra_repr(self):
#
# /lfs/1/jdunnmon/repos/anaconda3/envs/metal/lib/python3.6/site-packages/torch/nn/functional.py in linear(input, weight, bias)
#    1350     if input.dim() == 2 and bias is not None:
#    1351         # fused op is marginally faster
# -> 1352         ret = torch.addmm(torch.jit._unwrap_optional(bias), input, weight.t())
#    1353     else:
#    1354         output = input.matmul(weight.t())
#
# RuntimeError: Expected object of backend CPU but got backend CUDA for argument #4 'mat1'

# %% [markdown]
# ### Confirm that slice heads are actually experts at their jobs...

# %%
for model_name in model_configs.keys():
    if model_name == 'soft_param':
        labels_to_tasks = {
            "labelset:slice_1:pred": "test_task:slice_1:pred",
            "labelset:slice_2:pred": "test_task:slice_2:pred",    
            "labelset:slice_1:ind": "test_task:slice_1:ind",
            "labelset:slice_2:ind": "test_task:slice_2:ind",
        }
    else:
        labels_to_tasks = {
            "labelset:slice_1:pred": "test_task:slice_1:pred",
            "labelset:slice_2:pred": "test_task:slice_2:pred",        
        }

    eval_payload.remap_labelsets(labels_to_tasks)
    if model_name in ["hard_param", "soft_param", "manual_reweighting"]:
        print(f"{'='*10}Evaluating {model_name}{'='*10}")
        score_and_visualize(trained_models[model_name], eval_payload)
# Out:
# labelset 'labelset_gold' -> task 'None' (originally, test_task).
# labelset 'labelset:remainder:pred' -> task 'None' (originally, test_task:remainder:pred).
# labelset 'labelset:remainder:ind' -> task 'None' (originally, test_task:remainder:ind).
# ==========Evaluating soft_param==========
# Eval mapping...
# {   'labelset:remainder:ind': None,
#     'labelset:remainder:pred': None,
#     'labelset:slice_1:ind': 'test_task:slice_1:ind',
#     'labelset:slice_1:pred': 'test_task:slice_1:pred',
#     'labelset:slice_2:ind': 'test_task:slice_2:ind',
#     'labelset:slice_2:pred': 'test_task:slice_2:pred',
#     'labelset_gold': None}
# Model Scores:
# {   'test_task:slice_1:ind/payload_test/labelset:slice_1:ind/accuracy': 0.992,
#     'test_task:slice_1:pred/payload_test/labelset:slice_1:pred/accuracy': 0.9705882352941176,
#     'test_task:slice_2:ind/payload_test/labelset:slice_2:ind/accuracy': 0.9744,
#     'test_task:slice_2:pred/payload_test/labelset:slice_2:pred/accuracy': 0.78125}
# Vizualizing test_task:slice_1:pred predictions on labelset:slice_1:pred
# /lfs/1/jdunnmon/repos/anaconda3/envs/metal/lib/python3.6/site-packages/matplotlib/figure.py:98: MatplotlibDeprecationWarning:
# Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   "Adding an axes using the same arguments as a previous axes "
# Vizualizing test_task:slice_1:ind predictions on labelset:slice_1:ind
# Vizualizing test_task:slice_2:pred predictions on labelset:slice_2:pred
# Vizualizing test_task:slice_2:ind predictions on labelset:slice_2:ind
# labelset 'labelset:slice_1:ind' -> task 'None' (originally, test_task:slice_1:ind).
# labelset 'labelset:slice_2:ind' -> task 'None' (originally, test_task:slice_2:ind).
# ==========Evaluating hard_param==========
# Eval mapping...
# {   'labelset:remainder:ind': None,
#     'labelset:remainder:pred': None,
#     'labelset:slice_1:ind': None,
#     'labelset:slice_1:pred': 'test_task:slice_1:pred',
#     'labelset:slice_2:ind': None,
#     'labelset:slice_2:pred': 'test_task:slice_2:pred',
#     'labelset_gold': None}
# Model Scores:
# {   'test_task:slice_1:pred/payload_test/labelset:slice_1:pred/accuracy': 0.9117647058823529,
#     'test_task:slice_2:pred/payload_test/labelset:slice_2:pred/accuracy': 0.8125}
# Vizualizing test_task:slice_1:pred predictions on labelset:slice_1:pred
# Vizualizing test_task:slice_2:pred predictions on labelset:slice_2:pred
# ==========Evaluating manual_reweighting==========
# Eval mapping...
# {   'labelset:remainder:ind': None,
#     'labelset:remainder:pred': None,
#     'labelset:slice_1:ind': None,
#     'labelset:slice_1:pred': 'test_task:slice_1:pred',
#     'labelset:slice_2:ind': None,
#     'labelset:slice_2:pred': 'test_task:slice_2:pred',
#     'labelset_gold': None}
# Model Scores:
# {   'test_task:slice_1:pred/payload_test/labelset:slice_1:pred/accuracy': 0.9411764705882353,
#     'test_task:slice_2:pred/payload_test/labelset:slice_2:pred/accuracy': 0.84375}
# Vizualizing test_task:slice_1:pred predictions on labelset:slice_1:pred
# Vizualizing test_task:slice_2:pred predictions on labelset:slice_2:pred

# %% [markdown]
# ### Evaluate model on primary task head

# %%
# map all labelsets to the primary task_head 
eval_payload.remap_labelsets(labels_to_tasks= {
        "labelset_gold": "test_task",
        "labelset:slice_1:pred": "test_task",
        "labelset:slice_2:pred": "test_task",
        "labelset:remainder:pred": "test_task"
    }
)

for model_name in model_configs.keys():
    print(f"{'='*10}Evaluating {model_name}{'='*10}")
    score_and_visualize(trained_models[model_name], eval_payload)
# Out:
# labelset 'labelset_gold' -> task 'test_task' (originally, None).
# labelset 'labelset:slice_1:pred' -> task 'test_task' (originally, test_task:slice_1:pred).
# labelset 'labelset:slice_2:pred' -> task 'test_task' (originally, test_task:slice_2:pred).
# labelset 'labelset:remainder:pred' -> task 'test_task' (originally, None).
# ==========Evaluating soft_param==========
# Eval mapping...
# {   'labelset:remainder:ind': None,
#     'labelset:remainder:pred': 'test_task',
#     'labelset:slice_1:ind': None,
#     'labelset:slice_1:pred': 'test_task',
#     'labelset:slice_2:ind': None,
#     'labelset:slice_2:pred': 'test_task',
#     'labelset_gold': 'test_task'}
# Model Scores:
# {   'test_task/payload_test/labelset:remainder:pred/accuracy': 0.9932432432432432,
#     'test_task/payload_test/labelset:slice_1:pred/accuracy': 0.8823529411764706,
#     'test_task/payload_test/labelset:slice_2:pred/accuracy': 0.875,
#     'test_task/payload_test/labelset_gold/accuracy': 0.9872}
# Vizualizing test_task predictions on labelset_gold
# /lfs/1/jdunnmon/repos/anaconda3/envs/metal/lib/python3.6/site-packages/matplotlib/figure.py:98: MatplotlibDeprecationWarning:
# Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   "Adding an axes using the same arguments as a previous axes "
# Vizualizing test_task predictions on labelset:slice_1:pred
# Vizualizing test_task predictions on labelset:slice_2:pred
# Vizualizing test_task predictions on labelset:remainder:pred
# ==========Evaluating hard_param==========
# Eval mapping...
# {   'labelset:remainder:ind': None,
#     'labelset:remainder:pred': 'test_task',
#     'labelset:slice_1:ind': None,
#     'labelset:slice_1:pred': 'test_task',
#     'labelset:slice_2:ind': None,
#     'labelset:slice_2:pred': 'test_task',
#     'labelset_gold': 'test_task'}
# Model Scores:
# {   'test_task/payload_test/labelset:remainder:pred/accuracy': 0.9847972972972973,
#     'test_task/payload_test/labelset:slice_1:pred/accuracy': 0.5294117647058824,
#     'test_task/payload_test/labelset:slice_2:pred/accuracy': 0.625,
#     'test_task/payload_test/labelset_gold/accuracy': 0.9632}
# Vizualizing test_task predictions on labelset_gold
# Vizualizing test_task predictions on labelset:slice_1:pred
# Vizualizing test_task predictions on labelset:slice_2:pred
# Vizualizing test_task predictions on labelset:remainder:pred
# ==========Evaluating manual_reweighting==========
# Eval mapping...
# {   'labelset:remainder:ind': None,
#     'labelset:remainder:pred': 'test_task',
#     'labelset:slice_1:ind': None,
#     'labelset:slice_1:pred': 'test_task',
#     'labelset:slice_2:ind': None,
#     'labelset:slice_2:pred': 'test_task',
#     'labelset_gold': 'test_task'}
# Model Scores:
# {   'test_task/payload_test/labelset:remainder:pred/accuracy': 0.9890202702702703,
#     'test_task/payload_test/labelset:slice_1:pred/accuracy': 0.5294117647058824,
#     'test_task/payload_test/labelset:slice_2:pred/accuracy': 0.5625,
#     'test_task/payload_test/labelset_gold/accuracy': 0.9656}
# Vizualizing test_task predictions on labelset_gold
# Vizualizing test_task predictions on labelset:slice_1:pred
# Vizualizing test_task predictions on labelset:slice_2:pred
# Vizualizing test_task predictions on labelset:remainder:pred
# ==========Evaluating moe==========
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-15-55e353acd009> in <module>()
#      10 for model_name in model_configs.keys():
#      11     print(f"{'='*10}Evaluating {model_name}{'='*10}")
# ---> 12     score_and_visualize(trained_models[model_name], eval_payload)
#
# KeyError: 'moe'

# %% [markdown]
# ### Visualize Attention Weights of `soft_param`

# %%
for model_name in trained_models.keys():
    if model_name != 'soft_param':
        continue

    eval_payload.remap_labelsets(labels_to_tasks = {
            "labelset:slice_1:ind": "test_task:slice_1:ind",
            "labelset:slice_2:ind": "test_task:slice_2:ind"
        }
    )

    visualize_attention(trained_models['soft_param'], eval_payload)
# Out:
# labelset 'labelset_gold' -> task 'None' (originally, test_task).
# labelset 'labelset:slice_1:pred' -> task 'None' (originally, test_task).
# labelset 'labelset:slice_1:ind' -> task 'test_task:slice_1:ind' (originally, None).
# labelset 'labelset:slice_2:pred' -> task 'None' (originally, test_task).
# labelset 'labelset:slice_2:ind' -> task 'test_task:slice_2:ind' (originally, None).
# labelset 'labelset:remainder:pred' -> task 'None' (originally, test_task).
# Vizualizing test_task:BASE:ind attention on labelset:slice_1:ind
# /lfs/1/jdunnmon/repos/anaconda3/envs/metal/lib/python3.6/site-packages/matplotlib/figure.py:98: MatplotlibDeprecationWarning:
# Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   "Adding an axes using the same arguments as a previous axes "
# Vizualizing test_task:slice_1:ind attention on labelset:slice_1:ind
# Vizualizing test_task:slice_2:ind attention on labelset:slice_1:ind
# Vizualizing test_task:BASE:ind attention on labelset:slice_2:ind
# Vizualizing test_task:slice_1:ind attention on labelset:slice_2:ind
# Vizualizing test_task:slice_2:ind attention on labelset:slice_2:ind
